# %%
import pandas as pd

# %%
# Your raw data
data = {
    1: {'ellipse_diameter': 0.03612302, 'circle_diameter': 0.035806965749977, 'real_depth': 0.6993414, 'relative_depth': 1.332994, 'number_of_pixel': 28511},
    10: {'ellipse_diameter': 0.052214254, 'circle_diameter': 0.05097425809293727, 'real_depth': 0.7971238, 'relative_depth': 1.4698205, 'number_of_pixel': 44474},
    11: {'ellipse_diameter': 0.048020247, 'circle_diameter': 0.04702759456457461, 'real_depth': 0.73058486, 'relative_depth': 1.3767128, 'number_of_pixel': 45063},
    12: {'ellipse_diameter': 0.027889475, 'circle_diameter': 0.026881943874059573, 'real_depth': 0.44351518, 'relative_depth': 0.9750173, 'number_of_pixel': 39954},
    13: {'ellipse_diameter': 0.047587577, 'circle_diameter': 0.0475328132870087, 'real_depth': 0.984674, 'relative_depth': 1.7322588, 'number_of_pixel': 25343},
    14: {'ellipse_diameter': 0.05233824, 'circle_diameter': 0.051846929186057926, 'real_depth': 0.9767703, 'relative_depth': 1.7211992, 'number_of_pixel': 30642},
    15: {'ellipse_diameter': 0.029558629, 'circle_diameter': 0.015341733047595387, 'real_depth': 0.38051653, 'relative_depth': 0.8868636, 'number_of_pixel': 17679},
    16: {'ellipse_diameter': 1.4313569, 'circle_diameter': 1.0633017299520406, 'real_depth': 1.3038747, 'relative_depth': 2.178915, 'number_of_pixel': 7232646},
    17: {'ellipse_diameter': 0.0541156, 'circle_diameter': 0.05432352416813529, 'real_depth': 0.5784048, 'relative_depth': 1.1637678, 'number_of_pixel': 95933},
    18: {'ellipse_diameter': 0.0536089, 'circle_diameter': 0.053658688668139255, 'real_depth': 0.60483754, 'relative_depth': 1.2007551, 'number_of_pixel': 85597},
    19: {'ellipse_diameter': 1.4199789, 'circle_diameter': 0.8805789364854845, 'real_depth': 1.0334604, 'relative_depth': 1.8005254, 'number_of_pixel': 7895958},
    2: {'ellipse_diameter': 0.035323285, 'circle_diameter': 0.03500260565975215, 'real_depth': 0.7789546, 'relative_depth': 1.4443965, 'number_of_pixel': 21960},
    20: {'ellipse_diameter': 1.1992855, 'circle_diameter': 0.8659027792631221, 'real_depth': 0.99982417, 'relative_depth': 1.7534583, 'number_of_pixel': 8157309},
    21: {'ellipse_diameter': 1.4375893, 'circle_diameter': 0.8590516320726033, 'real_depth': 1.0455395, 'relative_depth': 1.8174276, 'number_of_pixel': 7341986},
    22: {'ellipse_diameter': 1.3825964, 'circle_diameter': 0.9599094420665454, 'real_depth': 1.1452669, 'relative_depth': 1.9569757, 'number_of_pixel': 7640170},
    23: {'ellipse_diameter': 1.2084916, 'circle_diameter': 0.8989405483962627, 'real_depth': 1.0854001, 'relative_depth': 1.8732044, 'number_of_pixel': 7459988},
    24: {'ellipse_diameter': 1.6762377, 'circle_diameter': 0.9549200729374273, 'real_depth': 1.1490092, 'relative_depth': 1.9622123, 'number_of_pixel': 7511781},
    25: {'ellipse_diameter': 1.2486511, 'circle_diameter': 0.8289124626599644, 'real_depth': 0.96921873, 'relative_depth': 1.7106323, 'number_of_pixel': 7954807},
    26: {'ellipse_diameter': 0.039446447, 'circle_diameter': 0.038988325110144356, 'real_depth': 0.6936429, 'relative_depth': 1.3250201, 'number_of_pixel': 34360},
    27: {'ellipse_diameter': 0.04177464, 'circle_diameter': 0.04119008409378468, 'real_depth': 0.2990144, 'relative_depth': 0.7728179, 'number_of_pixel': 206375},
    28: {'ellipse_diameter': 0.036503915, 'circle_diameter': 0.03574810575197315, 'real_depth': 0.32320285, 'relative_depth': 0.80666476, 'number_of_pixel': 133049},
    3: {'ellipse_diameter': 0.03543855, 'circle_diameter': 0.03469719042706902, 'real_depth': 0.58717513, 'relative_depth': 1.1760402, 'number_of_pixel': 37976},
    4: {'ellipse_diameter': 0.03243562, 'circle_diameter': 0.03205860479188798, 'real_depth': 0.27596307, 'relative_depth': 0.7405623, 'number_of_pixel': 146772},
    5: {'ellipse_diameter': 0.024755582, 'circle_diameter': 0.024406031423036673, 'real_depth': 0.15889287, 'relative_depth': 0.57674646, 'number_of_pixel': 256591},
    6: {'ellipse_diameter': 0.03355464, 'circle_diameter': 0.033203607691210474, 'real_depth': 0.5895184, 'relative_depth': 1.1793191, 'number_of_pixel': 34501},
    7: {'ellipse_diameter': 0.035003606, 'circle_diameter': 0.03441780719716281, 'real_depth': 0.39327276, 'relative_depth': 0.9047133, 'number_of_pixel': 83298},
    8: {'ellipse_diameter': 1.1040173, 'circle_diameter': 0.8640087758169317, 'real_depth': 1.12951, 'relative_depth': 1.9349272, 'number_of_pixel': 6363734},
    9: {'ellipse_diameter': 0.05083785, 'circle_diameter': 0.0497799801909699, 'real_depth': 0.4521513, 'relative_depth': 0.9871018, 'number_of_pixel': 131825}
}

# Convert to DataFrame
df = pd.DataFrame.from_dict(data, orient='index')
df.index.name = 'Image_ID'
df = df.reset_index()

# Filter out background (ignore objects > 0.1m)
df_filtered = df[df['circle_diameter'] < 0.6].copy()

# Add Comparison Columns (Target = 0.04m)
df_filtered['Target_Diameter'] = 0.04
df_filtered['Circle_Error_Metric'] = df_filtered['circle_diameter'] - 0.04
df_filtered['Circle_Error_Percent'] = (df_filtered['Circle_Error_Metric'] / 0.04) * 100
df_filtered['Ellipse_Error_Metric'] = df_filtered['circle_diameter'] - 0.04
df_filtered['Ellipse_Error_Percent'] = (df_filtered['Ellipse_Error_Metric'] / 0.04) * 100

# Save to CSV
df_filtered.to_csv('ball_1_analysis.csv', index=False)
print("File saved: ball_1_analysis.csv")
# Out:
# File saved: ball_1_analysis.csv

# %%
# Your raw data
data = {
    1: {'ellipse_diameter': 1.0124764, 'circle_diameter': 0.7180754735706559, 'real_depth': 0.8540026, 'relative_depth': 1.5494108, 'number_of_pixel': 7689139},
    10: {'ellipse_diameter': 0.045776397, 'circle_diameter': 0.04587244774658428, 'real_depth': 0.45716274, 'relative_depth': 0.99411434, 'number_of_pixel': 109501},
    11: {'ellipse_diameter': 1.3105142, 'circle_diameter': 0.838888121656608, 'real_depth': 1.0178233, 'relative_depth': 1.7786446, 'number_of_pixel': 7387869},
    12: {'ellipse_diameter': 1.3565816, 'circle_diameter': 0.9453913514905847, 'real_depth': 1.087234, 'relative_depth': 1.8757706, 'number_of_pixel': 8223053},
    13: {'ellipse_diameter': 1.1418626, 'circle_diameter': 0.9198649668666812, 'real_depth': 1.1104367, 'relative_depth': 1.9082379, 'number_of_pixel': 7463052},
    14: {'ellipse_diameter': 0.03555521, 'circle_diameter': 0.035662978858632316, 'real_depth': 0.26781136, 'relative_depth': 0.72915566, 'number_of_pixel': 192856},
    15: {'ellipse_diameter': 0.044959515, 'circle_diameter': 0.04503049364196434, 'real_depth': 0.50913286, 'relative_depth': 1.0668359, 'number_of_pixel': 85076},
    16: {'ellipse_diameter': 0.057646498, 'circle_diameter': 0.05593211019854039, 'real_depth': 0.42058337, 'relative_depth': 0.9429289, 'number_of_pixel': 192342},
    17: {'ellipse_diameter': 0.048615415, 'circle_diameter': 0.048637946686038214, 'real_depth': 0.6012537, 'relative_depth': 1.1957402, 'number_of_pixel': 71169},
    18: {'ellipse_diameter': 0.050681204, 'circle_diameter': 0.05029237506288815, 'real_depth': 0.5019248, 'relative_depth': 1.0567497, 'number_of_pixel': 109190},
    19: {'ellipse_diameter': 0.03686592, 'circle_diameter': 0.03659288786304005, 'real_depth': 0.38717735, 'relative_depth': 0.896184, 'number_of_pixel': 97147},
    2: {'ellipse_diameter': 1.0706376, 'circle_diameter': 0.724205655271622, 'real_depth': 0.86063814, 'relative_depth': 1.5586959, 'number_of_pixel': 7700848},
    20: {'ellipse_diameter': 1.210278, 'circle_diameter': 0.8660709253344429, 'real_depth': 0.9998145, 'relative_depth': 1.7534448, 'number_of_pixel': 8160635},
    21: {'ellipse_diameter': 1.5557796, 'circle_diameter': 0.8585184481530067, 'real_depth': 1.0454689, 'relative_depth': 1.8173289, 'number_of_pixel': 7333865},
    22: {'ellipse_diameter': 1.3031906, 'circle_diameter': 0.9601765731854164, 'real_depth': 1.1452707, 'relative_depth': 1.9569811, 'number_of_pixel': 7644372},
    23: {'ellipse_diameter': 0.034658365, 'circle_diameter': 0.03340585913381222, 'real_depth': 0.29196697, 'relative_depth': 0.7629565, 'number_of_pixel': 142375},
    24: {'ellipse_diameter': 0.05091426, 'circle_diameter': 0.049469675344517974, 'real_depth': 0.7584249, 'relative_depth': 1.4156692, 'number_of_pixel': 46271},
    25: {'ellipse_diameter': 0.037295774, 'circle_diameter': 0.036261243006943916, 'real_depth': 0.5770848, 'relative_depth': 1.1619208, 'number_of_pixel': 42940},
    26: {'ellipse_diameter': 0.035908762, 'circle_diameter': 0.03551890896168856, 'real_depth': 0.53337044, 'relative_depth': 1.1007514, 'number_of_pixel': 48230},
    27: {'ellipse_diameter': 0.050725665, 'circle_diameter': 0.050546947933800226, 'real_depth': 0.7435377, 'relative_depth': 1.3948377, 'number_of_pixel': 50262},
    28: {'ellipse_diameter': 1.1151749, 'circle_diameter': 0.8649322702763557, 'real_depth': 1.010802, 'relative_depth': 1.7688196, 'number_of_pixel': 7963205},
    3: {'ellipse_diameter': 1.0383167, 'circle_diameter': 0.7369544592884345, 'real_depth': 0.8809185, 'relative_depth': 1.5870742, 'number_of_pixel': 7611421},
    4: {'ellipse_diameter': 0.9220445, 'circle_diameter': 0.7247579974771894, 'real_depth': 0.86044466, 'relative_depth': 1.5584251, 'number_of_pixel': 7716068},
    5: {'ellipse_diameter': 0.9154065, 'circle_diameter': 0.6943214831816059, 'real_depth': 0.8842441, 'relative_depth': 1.5917276, 'number_of_pixel': 6705525},
    6: {'ellipse_diameter': 1.0116024, 'circle_diameter': 0.6396395119496191, 'real_depth': 0.81377006, 'relative_depth': 1.4931135, 'number_of_pixel': 6719285},
    7: {'ellipse_diameter': 0.92320305, 'circle_diameter': 0.7385195273208961, 'real_depth': 0.8987422, 'relative_depth': 1.6120147, 'number_of_pixel': 7343610},
    8: {'ellipse_diameter': 0.033187676, 'circle_diameter': 0.03227357170795493, 'real_depth': 0.21646747, 'relative_depth': 0.65731037, 'number_of_pixel': 241749},
    9: {'ellipse_diameter': 0.046730164, 'circle_diameter': 0.04685902033066663, 'real_depth': 0.4646836, 'relative_depth': 1.0046382, 'number_of_pixel': 110593}
}
# Convert to DataFrame
df = pd.DataFrame.from_dict(data, orient='index')
df.index.name = 'Image_ID'
df = df.reset_index()

# Filter out background (ignore objects > 0.1m)
df_filtered = df[df['circle_diameter'] < 0.6].copy()

# Add Comparison Columns (Target = 0.04m)
df_filtered['Target_Diameter'] = 0.038
df_filtered['Circle_Error_Metric'] = df_filtered['circle_diameter'] - 0.038
df_filtered['Circle_Error_Percent'] = (df_filtered['Circle_Error_Metric'] / 0.038) * 100
df_filtered['Ellipse_Error_Metric'] = df_filtered['ellipse_diameter'] - 0.038
df_filtered['Ellipse_Error_Percent'] = (df_filtered['Ellipse_Error_Metric'] / 0.038) * 100

# Save to CSV
df_filtered.to_csv('ball_2_analysis.csv', index=False)
print("File saved: ball_2_analysis.csv")
# Out:
# File saved: ball_2_analysis.csv

# %%
data = {
    10: {'ellipse_diameter': 0.03539066, 'circle_diameter': 0.03529239077613946, 'real_depth': 0.7563739, 'relative_depth': 1.4127992, 'number_of_pixel': 23678},
    11: {'ellipse_diameter': 0.030541364, 'circle_diameter': 0.0303970348058966, 'real_depth': 0.64967734, 'relative_depth': 1.2634993, 'number_of_pixel': 23808},
    12: {'ellipse_diameter': 0.02789077, 'circle_diameter': 0.026890934885739102, 'real_depth': 0.44351923, 'relative_depth': 0.97502303, 'number_of_pixel': 39980},
    14: {'ellipse_diameter': 0.023245035, 'circle_diameter': 0.023243523788279267, 'real_depth': 0.22487146, 'relative_depth': 0.66907, 'number_of_pixel': 116196},
    15: {'ellipse_diameter': 0.031106869, 'circle_diameter': 0.031146433622544708, 'real_depth': 0.40787774, 'relative_depth': 0.92515, 'number_of_pixel': 63418},
    16: {'ellipse_diameter': 0.04162979, 'circle_diameter': 0.04140250608287758, 'real_depth': 0.46539706, 'relative_depth': 1.0056366, 'number_of_pixel': 86072},
    17: {'ellipse_diameter': 0.036940303, 'circle_diameter': 0.035675222781721874, 'real_depth': 0.72860277, 'relative_depth': 1.3739393, 'number_of_pixel': 26074},
    18: {'ellipse_diameter': 0.034867994, 'circle_diameter': 0.03378576040476047, 'real_depth': 1.0150049, 'relative_depth': 1.7747006, 'number_of_pixel': 12050},
    19: {'ellipse_diameter': 0.028651174, 'circle_diameter': 0.027534463470543925, 'real_depth': 0.86024666, 'relative_depth': 1.5581481, 'number_of_pixel': 11142},
    20: {'ellipse_diameter': 0.027593868, 'circle_diameter': 0.026510682869858932, 'real_depth': 0.82475257, 'relative_depth': 1.5084813, 'number_of_pixel': 11237},
    21: {'ellipse_diameter': 0.031742636, 'circle_diameter': 0.031044831537170806, 'real_depth': 0.6101649, 'relative_depth': 1.2082096, 'number_of_pixel': 28154},
    22: {'ellipse_diameter': 0.028184751, 'circle_diameter': 0.02708308105314896, 'real_depth': 0.35953212, 'relative_depth': 0.85750014, 'number_of_pixel': 61713},
    3: {'ellipse_diameter': 0.114364654, 'circle_diameter': 0.0370202708812621, 'real_depth': 0.861496, 'relative_depth': 1.5598962, 'number_of_pixel': 20083},
    9: {'ellipse_diameter': 0.03382624, 'circle_diameter': 0.03361167575661921, 'real_depth': 0.42403924, 'relative_depth': 0.94776475, 'number_of_pixel': 68332}
}

df = pd.DataFrame.from_dict(data, orient='index')
df.index.name = 'Image_ID'
df = df.reset_index()

# Filter out background (ignore objects > 0.1m)
df_filtered = df[df['circle_diameter'] < 0.6].copy()

# Add Comparison Columns (Target = 0.04m)
df_filtered['Target_Diameter'] = 0.025
df_filtered['Circle_Error_Metric'] = df_filtered['circle_diameter'] - 0.025
df_filtered['Circle_Error_Percent'] = (df_filtered['Circle_Error_Metric'] / 0.025) * 100
df_filtered['Ellipse_Error_Metric'] = df_filtered['ellipse_diameter'] - 0.025
df_filtered['Ellipse_Error_Percent'] = (df_filtered['Ellipse_Error_Metric'] / 0.025) * 100

# Save to CSV
df_filtered.to_csv('ball_3_analysis.csv', index=False)
print("File saved: ball_3_analysis.csv")
# Out:
# File saved: ball_3_analysis.csv

# %%
data = {
    8: {'ellipse_diameter': 0.041980978, 'circle_diameter': 0.0416081481020815, 'real_depth': 0.3344109, 'relative_depth': 0.8223482, 'number_of_pixel': 168365},
    9: {'ellipse_diameter': 0.045986675, 'circle_diameter': 0.04600643402464945, 'real_depth': 0.34605938, 'relative_depth': 0.8386478, 'number_of_pixel': 192217},
    10: {'ellipse_diameter': 0.042722028, 'circle_diameter': 0.04274446368633458, 'real_depth': 0.32559943, 'relative_depth': 0.8100183, 'number_of_pixel': 187434},
    11: {'ellipse_diameter': 0.04894422, 'circle_diameter': 0.04889795704938693, 'real_depth': 0.6400853, 'relative_depth': 1.2500771, 'number_of_pixel': 63469},
    13: {'ellipse_diameter': 0.043950703, 'circle_diameter': 0.04280222631316194, 'real_depth': 0.41182816, 'relative_depth': 0.93067783, 'number_of_pixel': 117478},
    14: {'ellipse_diameter': 0.05096443, 'circle_diameter': 0.049761573872862765, 'real_depth': 0.7892405, 'relative_depth': 1.4587893, 'number_of_pixel': 43234},
    15: {'ellipse_diameter': 0.048648454, 'circle_diameter': 0.04876424409157915, 'real_depth': 0.55173415, 'relative_depth': 1.1264477, 'number_of_pixel': 84957},
    17: {'ellipse_diameter': 0.04495431, 'circle_diameter': 0.04476164372077524, 'real_depth': 0.29424536, 'relative_depth': 0.7661447, 'number_of_pixel': 251680},
    18: {'ellipse_diameter': 0.040145136, 'circle_diameter': 0.04018407674143608, 'real_depth': 0.25160503, 'relative_depth': 0.7064782, 'number_of_pixel': 277412},
    22: {'ellipse_diameter': 0.050808553, 'circle_diameter': 0.0505727386249681, 'real_depth': 0.7428832, 'relative_depth': 1.3939219, 'number_of_pixel': 50402},
    23: {'ellipse_diameter': 0.044070583, 'circle_diameter': 0.04347416995150437, 'real_depth': 0.76373255, 'relative_depth': 1.4230962, 'number_of_pixel': 35240},
    24: {'ellipse_diameter': 0.039964836, 'circle_diameter': 0.03989052050019683, 'real_depth': 0.2569945, 'relative_depth': 0.71401966, 'number_of_pixel': 262028}
}


df = pd.DataFrame.from_dict(data, orient='index')
df.index.name = 'Image_ID'
df = df.reset_index()

# Filter out background (ignore objects > 0.1m)
df_filtered = df[df['circle_diameter'] < 0.6].copy()

# Add Comparison Columns (Target = 0.04m)
df_filtered['Target_Diameter'] = 0.04
df_filtered['Circle_Error_Metric'] = df_filtered['circle_diameter'] - 0.04
df_filtered['Circle_Error_Percent'] = (df_filtered['Circle_Error_Metric'] / 0.04) * 100
df_filtered['Ellipse_Error_Metric'] = df_filtered['ellipse_diameter'] - 0.04
df_filtered['Ellipse_Error_Percent'] = (df_filtered['Ellipse_Error_Metric'] / 0.04) * 100

# Save to CSV
df_filtered.to_csv('ball_4_analysis.csv', index=False)
print("File saved: ball_4_analysis.csv")
# Out:
# File saved: ball_4_analysis.csv

# %%
data = {
    29: {'ellipse_diameter': 0.08333013, 'circle_diameter': 0.08275706747844282, 'real_depth': 0.633896, 'relative_depth': 1.2414165, 'number_of_pixel': 185366},
    30: {'ellipse_diameter': 0.077914, 'circle_diameter': 0.07744051459795936, 'real_depth': 0.42236656, 'relative_depth': 0.94542414, 'number_of_pixel': 365606},
    31: {'ellipse_diameter': 0.07951451, 'circle_diameter': 0.07963304997230458, 'real_depth': 0.5156765, 'relative_depth': 1.0759923, 'number_of_pixel': 259351},
    32: {'ellipse_diameter': 0.07836297, 'circle_diameter': 0.07769968899717115, 'real_depth': 0.76954556, 'relative_depth': 1.4312303, 'number_of_pixel': 110873},
    33: {'ellipse_diameter': 0.090994954, 'circle_diameter': 0.08967601819177133, 'real_depth': 0.6292598, 'relative_depth': 1.2349291, 'number_of_pixel': 220876}
}


df = pd.DataFrame.from_dict(data, orient='index')
df.index.name = 'Image_ID'
df = df.reset_index()

# Filter out background (ignore objects > 0.1m)
df_filtered = df[df['circle_diameter'] < 0.6].copy()

# Add Comparison Columns (Target = 0.04m)
df_filtered['Target_Diameter'] = 0.073
df_filtered['Circle_Error_Metric'] = df_filtered['circle_diameter'] - 0.073
df_filtered['Circle_Error_Percent'] = (df_filtered['Circle_Error_Metric'] / 0.073) * 100
df_filtered['Ellipse_Error_Metric'] = df_filtered['ellipse_diameter'] - 0.073
df_filtered['Ellipse_Error_Percent'] = (df_filtered['Ellipse_Error_Metric'] / 0.073) * 100

# Save to CSV
df_filtered.to_csv('ball_5_analysis.csv', index=False)
print("File saved: ball_5_analysis.csv")
# Out:
# File saved: ball_5_analysis.csv
